# %%
lis=[4,3,2,4,2]
lis1=[3,4,56,6,4,]

# %%
lis.append(lis1)

# %%
lis
# Out:
# [4, 3, 2, 4, 2, [3, 4, 56, 6, 4]]

# %%
import pandas as pb

# %%
ser=pb.Series(lis)
ser
# Out:
# 0                   4
# 1                   3
# 2                   2
# 3                   4
# 4                   2
# 5    [3, 4, 56, 6, 4]
# dtype: object

# %%
lis3=[2,4,3,2,5],[4,6,3,6,5]
ser1=pb.Series(lis3)

# %%
ser1
# Out:
# 0    [2, 4, 3, 2, 5]
# 1    [4, 6, 3, 6, 5]
# dtype: object

# %%
lis3=[[2,4,3,2,5],[4,6,3,6,5]]
ser1=pb.Series(lis3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 2
#       1 lis3=[[2,4,3,2,5],[4,6,3,6,5]]
# ----> 2 ser1=pb.Series(lis3)
#
# NameError: name 'pb' is not defined

# %%
import pandas as pb

# %%
lis3=[[2,4,3,2,5],[4,6,3,6,5]]
ser1=pb.Series(lis3)

# %%
ser1
# Out:
# 0    [2, 4, 3, 2, 5]
# 1    [4, 6, 3, 6, 5]
# dtype: object

# %%
df=pb.DataFrame(lis3)
df
# Out:
#    0  1  2  3  4
# 0  2  4  3  2  5
# 1  4  6  3  6  5

# %%
df=pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/titanic.csv')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 df=pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/titanic.csv')
#       2 df
#
# NameError: name 'pd' is not defined

# %%
df=pb.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail(6)
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 150          151         0       2         Bateman, Rev. Robert James    male
# 151          152         1       1  Pears, Mrs. Thomas (Edith Wearne)  female
# 152          153         0       3                   Meo, Mr. Alfonzo    male
# 153          154         0       3    van Billiard, Mr. Austin Blyler    male
# 154          155         0       3              Olsen, Mr. Ole Martin    male
# 155          156         0       1        Williams, Mr. Charles Duane    male
#
#       Age  SibSp  Parch       Ticket     Fare Cabin Embarked
# 150  51.0      0      0  S.O.P. 1166  12.5250   NaN        S
# 151  22.0      1      0       113776  66.6000    C2        S
# 152  55.5      0      0   A.5. 11206   8.0500   NaN        S
# 153  40.5      0      2     A/5. 851  14.5000   NaN        S
# 154   NaN      0      0    Fa 265302   7.3125   NaN        S
# ...

# %%
df[50:100]
# Out:
#     PassengerId  Survived  Pclass  \
# 50           51         0       3
# 51           52         0       3
# 52           53         1       1
# 53           54         1       2
# 54           55         0       1
# 55           56         1       1
# 56           57         1       2
# 57           58         0       3
# 58           59         1       2
# 59           60         0       3
# 60           61         0       3
# 61           62         1       1
# 62           63         0       1
# 63           64         0       3
# 64           65         0       1
# 65           66         1       3
# 66           67         1       2
# 67           68         0       3
# 68           69         1       3
# 69           70         0       3
# 70           71         0       2
# 71           72         0       3
# 72           73         0       2
# 73           74         0       3
# 74           75         1       3
# 75           76         0       3
# ...

# %%
df[50:100;5]
# Out:
#   Cell In [12], line 1
#     df[50:100;5]
#              ^
# SyntaxError: invalid syntax

# %%
df[50:100:5]
# Out:
#     PassengerId  Survived  Pclass  \
# 50           51         0       3
# 55           56         1       1
# 60           61         0       3
# 65           66         1       3
# 70           71         0       2
# 75           76         0       3
# 80           81         0       3
# 85           86         1       3
# 90           91         0       3
# 95           96         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 50                         Panula, Master. Juha Niilo    male   7.0      4
# 55                                  Woolner, Mr. Hugh    male   NaN      0
# 60                              Sirayanian, Mr. Orsen    male  22.0      0
# 65                           Moubarek, Master. Gerios    male   NaN      1
# 70                         Jenkin, Mr. Stephen Curnow    male  32.0      0
# 75                            Moen, Mr. Sigurd Hansen    male  25.0      0
# ...

# %%
df[30]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 30
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[0:30]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
df.types
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 df.types
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'types'

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
df.shape
# Out:
# (156, 12)

# %%
df.Fare
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 151    66.6000
# 152     8.0500
# 153    14.5000
# 154     7.3125
# 155    61.3792
# Name: Fare, Length: 156, dtype: float64

# %%
df.('Fare')
# Out:
#   Cell In [21], line 1
#     df.('Fare')
#        ^
# SyntaxError: invalid syntax

# %%
df['fare']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'fare'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 151    66.6000
# 152     8.0500
# 153    14.5000
# 154     7.3125
# 155    61.3792
# Name: Fare, Length: 156, dtype: float64

# %%
df['Fare','Ticket']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Fare', 'Ticket')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[['Fare','Ticket']]
# Out:
#         Fare            Ticket
# 0     7.2500         A/5 21171
# 1    71.2833          PC 17599
# 2     7.9250  STON/O2. 3101282
# 3    53.1000            113803
# 4     8.0500            373450
# ..       ...               ...
# 151  66.6000            113776
# 152   8.0500        A.5. 11206
# 153  14.5000          A/5. 851
# 154   7.3125         Fa 265302
# 155  61.3792          PC 17597
#
# [156 rows x 2 columns]

# %%
df['Ticket'].unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
# ...

# %%
type(df['Ticket'].unique())
# Out:
# numpy.ndarray

# %%
df.loc[50]
# Out:
# PassengerId                            51
# Survived                                0
# Pclass                                  3
# Name           Panula, Master. Juha Niilo
# Sex                                  male
# Age                                   7.0
# SibSp                                   4
# Parch                                   1
# Ticket                            3101295
# Fare                              39.6875
# Cabin                                 NaN
# Embarked                                S
# Name: 50, dtype: object

# %%
df.last
# Out:
# <bound method NDFrame.last of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.last(156)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [30], line 1
# ----> 1 df.last(156)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:9001, in NDFrame.last(self, offset)
#    8950 """
#    8951 Select final periods of time series data based on a date offset.
#    8952
#    (...)
#    8998 not returned.
#    8999 """
#    9000 if not isinstance(self.index, DatetimeIndex):
# -> 9001     raise TypeError("'last' only supports a DatetimeIndex index")
#    9003 if len(self.index) == 0:
#    9004     return self
#
# TypeError: 'last' only supports a DatetimeIndex index

# %%
df.last(155)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [31], line 1
# ----> 1 df.last(155)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:9001, in NDFrame.last(self, offset)
#    8950 """
#    8951 Select final periods of time series data based on a date offset.
#    8952
#    (...)
#    8998 not returned.
#    8999 """
#    9000 if not isinstance(self.index, DatetimeIndex):
# -> 9001     raise TypeError("'last' only supports a DatetimeIndex index")
#    9003 if len(self.index) == 0:
#    9004     return self
#
# TypeError: 'last' only supports a DatetimeIndex index

# %%
sd.tail(155)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [32], line 1
# ----> 1 sd.tail(155)
#
# NameError: name 'sd' is not defined

# %%
df.tail
# Out:
# <bound method NDFrame.tail of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.tail(155)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ad.loc[30:40]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [35], line 1
# ----> 1 ad.loc[30:40]
#
# NameError: name 'ad' is not defined

# %%
df.loc[30:40]
# Out:
#     PassengerId  Survived  Pclass  \
# 30           31         0       1
# 31           32         1       1
# 32           33         1       3
# 33           34         0       2
# 34           35         0       1
# 35           36         0       1
# 36           37         1       3
# 37           38         0       3
# 38           39         0       3
# 39           40         1       3
# 40           41         0       3
#
#                                               Name     Sex   Age  SibSp  \
# 30                        Uruchurtu, Don. Manuel E    male  40.0      0
# 31  Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 32                        Glynn, Miss. Mary Agatha  female   NaN      0
# 33                           Wheadon, Mr. Edward H    male  66.0      0
# 34                         Meyer, Mr. Edgar Joseph    male  28.0      1
# 35                  Holverson, Mr. Alexander Oskar    male  42.0      1
# ...

# %%
df.set_index('Ticket')
# Out:
#                   PassengerId  Survived  Pclass  \
# Ticket
# A/5 21171                   1         0       3
# PC 17599                    2         1       1
# STON/O2. 3101282            3         1       3
# 113803                      4         1       1
# 373450                      5         0       3
# ...                       ...       ...     ...
# 113776                    152         1       1
# A.5. 11206                153         0       3
# A/5. 851                  154         0       3
# Fa 265302                 155         0       3
# PC 17597                  156         0       1
#
#                                                                Name     Sex  \
# Ticket
# A/5 21171                                   Braund, Mr. Owen Harris    male
# PC 17599          Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# STON/O2. 3101282                             Heikkinen, Miss. Laina  female
# ...

# %%
id(df.set_index('Ticket'))
# Out:
# 140261088056064

# %%
id(df)
# Out:
# 140261206931200

# %%
df.set_index('PassengerId',inplace=True)

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 152                 1       1
# 153                 0       3
# 154                 0       3
# 155                 0       3
# 156                 0       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
F.loc(500
# Out:
#   Cell In [43], line 1
#     F.loc(500
#              ^
# SyntaxError: incomplete input

# %%
df.loc[50]
# Out:
# Survived                                                0
# Pclass                                                  3
# Name        Arnold-Franchi, Mrs. Josef (Josefine Franchi)
# Sex                                                female
# Age                                                  18.0
# SibSp                                                   1
# Parch                                                   0
# Ticket                                             349237
# Fare                                                 17.8
# Cabin                                                 NaN
# Embarked                                                S
# Name: 50, dtype: object

# %%
df.iloc[50]
# Out:
# Survived                             0
# Pclass                               3
# Name        Panula, Master. Juha Niilo
# Sex                               male
# Age                                7.0
# SibSp                                4
# Parch                                1
# Ticket                         3101295
# Fare                           39.6875
# Cabin                              NaN
# Embarked                             S
# Name: 51, dtype: object

# %%
df.isnull()
# Out:
#              Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# PassengerId
# 1               False   False  False  False  False  False  False   False
# 2               False   False  False  False  False  False  False   False
# 3               False   False  False  False  False  False  False   False
# 4               False   False  False  False  False  False  False   False
# 5               False   False  False  False  False  False  False   False
# ...               ...     ...    ...    ...    ...    ...    ...     ...
# 152             False   False  False  False  False  False  False   False
# 153             False   False  False  False  False  False  False   False
# 154             False   False  False  False  False  False  False   False
# 155             False   False  False  False   True  False  False   False
# 156             False   False  False  False  False  False  False   False
#
#               Fare  Cabin  Embarked
# PassengerId
# ...

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age          30
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       125
# Embarked      1
# dtype: int64

# %%
df['new_col']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'new_col'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['sum']=df['PassengerId']+df['Survive']+df['Pclass']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PassengerId'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['new_col']=df['Survived']+df['pclass']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pclass'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df=pb.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['new_col']=df['Survived'] + df['Pclass']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col
# 0      0         A/5 21171   7.2500   NaN        S        3
# 1      0          PC 17599  71.2833   C85        C        2
# 2      0  STON/O2. 3101282   7.9250   NaN        S        4
# 3      0            113803  53.1000  C123        S        2
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df isnull()
# Out:
#   Cell In [57], line 1
#     df isnull()
#        ^
# SyntaxError: invalid syntax

# %%
df.ilock[100]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [58], line 1
# ----> 1 df.ilock[100]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ilock'

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
df.ilock[100]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [60], line 1
# ----> 1 df.ilock[100]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ilock'

# %%
df.loc[100]
# Out:
# PassengerId                        101
# Survived                             0
# Pclass                               3
# Name           Petranec, Miss. Matilda
# Sex                             female
# Age                               28.0
# SibSp                                0
# Parch                                0
# Ticket                          349245
# Fare                            7.8958
# Cabin                              NaN
# Embarked                             S
# new_col                              3
# Name: 100, dtype: object

# %%
df.set_index('PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 152                 1       1
# 153                 0       3
# 154                 0       3
# 155                 0       3
# 156                 0       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.ilock[100]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [63], line 1
# ----> 1 df.ilock[100]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ilock'

# %%
df.iloc[100]
# Out:
# PassengerId                        101
# Survived                             0
# Pclass                               3
# Name           Petranec, Miss. Matilda
# Sex                             female
# Age                               28.0
# SibSp                                0
# Parch                                0
# Ticket                          349245
# Fare                            7.8958
# Cabin                              NaN
# Embarked                             S
# new_col                              3
# Name: 100, dtype: object

# %%
df.loc[100]
# Out:
# PassengerId                        101
# Survived                             0
# Pclass                               3
# Name           Petranec, Miss. Matilda
# Sex                             female
# Age                               28.0
# SibSp                                0
# Parch                                0
# Ticket                          349245
# Fare                            7.8958
# Cabin                              NaN
# Embarked                             S
# new_col                              3
# Name: 100, dtype: object

# %%
df.set_index('PassengerId',inplace=True)

# %%
id(df)
# Out:
# 140261084930032

# %%
id(df.set_index('PassengerId',inplace=True))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [68], line 1
# ----> 1 id(df.set_index('PassengerId',inplace=True))
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:6001, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5998                 missing.append(col)
#    6000 if missing:
# -> 6001     raise KeyError(f"None of {missing} are in the columns")
#    6003 if inplace:
# ...

# %%
id(df.set_index('PassengerId')
# Out:
#   Cell In [69], line 1
#     id(df.set_index('PassengerId')
#                                   ^
# SyntaxError: incomplete input

# %%
id(df.set_index('PassengerId'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [70], line 1
# ----> 1 id(df.set_index('PassengerId'))
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:6001, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5998                 missing.append(col)
#    6000 if missing:
# -> 6001     raise KeyError(f"None of {missing} are in the columns")
#    6003 if inplace:
# ...

# %%
df.loc[100]
# Out:
# Survived                    0
# Pclass                      2
# Name        Kantor, Mr. Sinai
# Sex                      male
# Age                      34.0
# SibSp                       1
# Parch                       0
# Ticket                 244367
# Fare                     26.0
# Cabin                     NaN
# Embarked                    S
# new_col                     2
# Name: 100, dtype: object

# %%
df.iloc[100]
# Out:
# Survived                          0
# Pclass                            3
# Name        Petranec, Miss. Matilda
# Sex                          female
# Age                            28.0
# SibSp                             0
# Parch                             0
# Ticket                       349245
# Fare                         7.8958
# Cabin                           NaN
# Embarked                          S
# new_col                           3
# Name: 101, dtype: object

# %%
id(df)
# Out:
# 140261084930032

# %%
df.inull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [74], line 1
# ----> 1 df.inull()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'inull'

# %%
df.isnull()
# Out:
#              Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# PassengerId
# 1               False   False  False  False  False  False  False   False
# 2               False   False  False  False  False  False  False   False
# 3               False   False  False  False  False  False  False   False
# 4               False   False  False  False  False  False  False   False
# 5               False   False  False  False  False  False  False   False
# ...               ...     ...    ...    ...    ...    ...    ...     ...
# 152             False   False  False  False  False  False  False   False
# 153             False   False  False  False  False  False  False   False
# 154             False   False  False  False  False  False  False   False
# 155             False   False  False  False   True  False  False   False
# 156             False   False  False  False  False  False  False   False
#
#               Fare  Cabin  Embarked  new_col
# PassengerId
# ...

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age          30
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       125
# Embarked      1
# new_col       0
# dtype: int64

# %%
df['new_col']=df['Survived']

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 152                 1       1
# 153                 0       3
# 154                 0       3
# 155                 0       3
# 156                 0       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.drop('new_col',axis=1,inplace=True)

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 152                 1       1
# 153                 0       3
# 154                 0       3
# 155                 0       3
# 156                 0       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
dict1={'name':['ravi','ashish','sonu','divya','ram','sayam'],
       'age':[23,43,43,12,23,45],
       'address':['purnea','assam','delhi','pakistan','noida','bihar'],
       'qualification':['ma','ba','be-d','be','mtech','btech'],
       'salary':[34333,44455,67667,99999,44444,65432]
      }

# %%
df=pb.DataFrame(dict1)

# %%
df
# Out:
#      name  age   address qualification  salary
# 0    ravi   23    purnea            ma   34333
# 1  ashish   43     assam            ba   44455
# 2    sonu   43     delhi          be-d   67667
# 3   divya   12  pakistan            be   99999
# 4     ram   23     noida         mtech   44444
# 5   sayam   45     bihar         btech   65432

# %%
df.groupby('name')
print(df.groupby('name').groups)
# Out:
# {'ashish': [1], 'divya': [3], 'ram': [4], 'ravi': [0], 'sayam': [5], 'sonu': [2]}

# %%
gk=df.groupby('name')
list(gk)
# Out:
# [('ashish',
#        name  age address qualification  salary
#   1  ashish   43   assam            ba   44455),
#  ('divya',
#       name  age   address qualification  salary
#   3  divya   12  pakistan            be   99999),
#  ('ram',
#     name  age address qualification  salary
#   4  ram   23   noida         mtech   44444),
#  ('ravi',
#      name  age address qualification  salary
#   0  ravi   23  purnea            ma   34333),
#  ('sayam',
#       name  age address qualification  salary
#   5  sayam   45   bihar         btech   65432),
#  ('sonu',
#      name  age address qualification  salary
#   2  sonu   43   delhi          be-d   67667)]

# %%
pb.DataFrame(gk)
# Out:
#         0                                                  1
# 0  ashish       name  age address qualification
# 1  ashish...
# 1   divya      name  age   address qualification
# 3  divya...
# 2     ram    name  age address qualification
# 4  ram   23 ...
# 3    ravi     name  age address qualification
# 0  ravi   2...
# 4   sayam      name  age address qualification
# 5  sayam  ...
# 5    sonu     name  age address qualification
# 2  sonu   4...

# %%
for i in gk:
    print(i)
# Out:
# ('ashish',      name  age address qualification
# 1  ashish   43   assam            ba)
# ('divya',     name  age   address qualification
# 3  divya   12  pakistan            be)
# ('ram',   name  age address qualification
# 4  ram   23   noida         mtech)
# ('ravi',    name  age address qualification
# 0  ravi   23  purnea            ma)
# ('sayam',     name  age address qualification
# 5  sayam   45   bihar         btech)
# ('sonu',    name  age address qualification
# 2  sonu   43   delhi          be-d)

# %%
pk=df.groupby(['name','age'])

# %%
pk

# %%
pk.groups
# Out:
# {('ashish', 43): [1], ('divya', 12): [3], ('ram', 23): [4], ('ravi', 23): [0], ('sayam', 45): [5], ('sonu', 43): [2]}

# %%
list(pk)
# Out:
# [(('ashish', 43),
#        name  age address qualification
#   1  ashish   43   assam            ba),
#  (('divya', 12),
#       name  age   address qualification
#   3  divya   12  pakistan            be),
#  (('ram', 23),
#     name  age address qualification
#   4  ram   23   noida         mtech),
#  (('ravi', 23),
#      name  age address qualification
#   0  ravi   23  purnea            ma),
#  (('sayam', 45),
#       name  age address qualification
#   5  sayam   45   bihar         btech),
#  (('sonu', 43),
#      name  age address qualification
#   2  sonu   43   delhi          be-d)]

# %%
df.groupby('name').sum('salaty')
# Out:
#         age  salary
# name
# ashish   43   44455
# divya    12   99999
# ram      23   44444
# ravi     23   34333
# sayam    45   65432
# sonu     43   67667

# %%
df.groupby('name').sum()
# Out:
# /tmp/ipykernel_77/2743881291.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('name').sum()
#         age  salary
# name
# ashish   43   44455
# divya    12   99999
# ram      23   44444
# ravi     23   34333
# sayam    45   65432
# sonu     43   67667

# %%
dict1={'name':['ravi','ashish','sonu'],
       'age':[23,43,43],
       'address':['purnea','assam','delhi'],
       'qualification':['ma','ba','be-d'],
       'salary':[34333,44455,67667]
      }

data2=dict1={'name':['divya','ram','sayam'],
       'age':[12,23,45],
       'address':['pakistan','noida','bihar'],
       'qualification':['be','mtech','btech'],
       'salary':[99999,44444,65432]
      }

# %%
df1=pb.DataFrame(dict1,index=[1,2,3])
df2=pb.DataFrame(data2,index=[4,5,6])

# %%
df1
# Out:
#     name  age   address qualification  salary
# 1  divya   12  pakistan            be   99999
# 2    ram   23     noida         mtech   44444
# 3  sayam   45     bihar         btech   65432

# %%
df2
# Out:
#     name  age   address qualification  salary
# 4  divya   12  pakistan            be   99999
# 5    ram   23     noida         mtech   44444
# 6  sayam   45     bihar         btech   65432

# %%
concat_1=[df1,df2]
res=pb.concat(concat_1)
res
# Out:
#     name  age   address qualification  salary
# 1  divya   12  pakistan            be   99999
# 2    ram   23     noida         mtech   44444
# 3  sayam   45     bihar         btech   65432
# 4  divya   12  pakistan            be   99999
# 5    ram   23     noida         mtech   44444
# 6  sayam   45     bihar         btech   65432
